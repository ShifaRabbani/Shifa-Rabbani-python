# %%
# Jupyter Notebook is a file where you can write Python code and see the result immediately.
# Hello world
print("Hello World")
# Out:
# Hello World

# %%
print(78+87)
# Out:
# 165

# %%
a=int(input("Enter a first number"))
b=int(input("Enter a 2nd number"))
print("a =",a)
print("b =",b)
print("Addition",a+b)
print("Subtraction",a-b)
print("Multiplication" , a*b)
print("Remainder",a/b)
print("Division",a/b)
# Out:
# a = 23
# b = 24
# Addition 47
# Subtraction -1
# Multiplication 552
# Remainder 0.9583333333333334
# Division 0.9583333333333334
