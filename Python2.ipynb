# %%
import math 
a =10
b = 3
print(a/b)
print(math.floor(a/b))
# Out:
# 3.3333333333333335
# 3

# %% [markdown]
# Task 2: given x=7,update x to x+1, then to x-2 , x*3, x/3(in seprate assigments)

# %%
x = 7
print(x)
x += 1
print(x)
x =x-1
print(x)
x = x*3
print(x)
x = x/ 3
print(x)
# Out:
# 7
# 8
# 7
# 21
# 7.0

# %% [markdown]
# Task 3: Swap a and b without using 3rd varaible

# %%
a = 2
b = 4
a = a+b
b = a+b 
a = b-a
b = b-a
b = b-a
print("a =",a)
print("b =",b)
# Out:
# a = 4
# b = 2

# %% [markdown]
# Task 4:Given price 450 and discout  = 15% (Compute final price after discount)

# %%
price = 450
discount= price * (15/100)
print(discount)
# Out:
# 67.5

# %% [markdown]
# Task 5 :give seconds 3672, compute houres , minuts,rmainig Seconds

# %% [markdown]
# Task 6: Given n=1,2,3,4,5, compute last digit and first (No Loop)

# %%
n=1,2,3,4,5
print(n)
print(n[0])
print(n[4])
# Out:
# (1, 2, 3, 4, 5)
# 1
# 5

# %% [markdown]
# Task 7:Given length=12 and width=8, compute area and perimeter.

# %%
length = 12
width = 8
area = length + width
print(area)
perameter = area * 2
print(perameter)
# Out:
# 20
# 40

# %% [markdown]
# Task 8:Given celsius=37, compute Fahrenheit.

# %% [markdown]
# # Strings basics

# %% [markdown]
# Task 21:Given s="python", get first char, last char, and middle char(s).

# %%
s= "python"
print(s[0])
print(s[3])
print(s[-1])
# Out:
# p
# h
# n

# %% [markdown]
# Task 22:Given s="hello world", extract "world" using slicing.

# %%
s = "Hello World"
x=slice(0,5)
print(s[x])
# Out:
# Hello

# %% [markdown]
# Task 23:Given s="  Data Science  ", remove extra spaces from both sides.

# %%
s= "  Data Science  " 
print(s)
print(s.strip())
# Out:
#   Data Science
# Data Science

# %% [markdown]
# Task 24:Given s="BANANA", make it lowercase.

# %%
s ="BANANA"
print(s.lower())
# Out:
# banana

# %% [markdown]
# Task 25:Given s="paKisTaN", make it all uppercase and all lowercase (two variables).

# %%
s = "paKisTaN"
l = s.lower()
print(l)
u = s.upper()
print(u)
# Out:
# pakistan
# PAKISTAN

# %% [markdown]
# Task 26: Given s="abc123", separate letters part and digits part using slicing

# %%
s = "123AbC"
t = slice(0,3)
print(s[t]) 
print(s)  # slice can not change the orignal string
y = slice(3,6)
print(s[y])
# Out:
# 123
# 123AbC
# AbC

# %% [markdown]
# Task 27:Given s="mississippi", count how many times "s" occurs.

# %%
s = "mississippi"
print(s.count("s"))
# Out:
# 4
